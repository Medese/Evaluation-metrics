# %%
"HOUSE PRICE PREDICTION"
# Out:
# 'HOUSE PRICE PREDICTION'

# %% [markdown]
# Before calculating evaluation metrics, we need to define `y_test` (the actual target values from your test set) and `y_pred` (the predictions made by your model). For now, I'll create some sample arrays. You should replace these with the actual values from your project.

# %%
y_test = np.array([100000, 150000, 200000, 250000, 300000])
y_pred = np.array([105000, 148000, 210000, 245000, 290000])

# %%
mse = mean_squared_error(y_test,y_pred)
rmse =np.sqrt(mse)
mae =mean_absolute_error(y_test,y_pred)
r2 =r2_score(y_test,y_pred)

# %%
print(f"Mean Squared Error (MSE):", mse)
print(f"Root Mean Squared Error (RMSE):", rmse)
print(f"Mean Absolute Error (MAE):", mae)
print(f"R-squared (R2):", r2)
# Out:
# Mean Squared Error (MSE): 50800000.0
# Root Mean Squared Error (RMSE): 7127.411872482185
# Mean Absolute Error (MAE): 6400.0
# R-squared (R2): 0.98984
